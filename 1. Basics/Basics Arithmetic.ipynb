# %% [markdown]
# ### First Lecture

# %% [markdown]
# #### Basic Arithmetic

# %%
#Division
8/3 #This gives me quotient
# Out:
# 2.6666666666666665

# %%
#Floor Division 
8//3 #a division to the nearest integer toward negative infinity
# Out:
# 2

# %%
#Modulo
7%2 #This gives me remainder
# Out:
# 1

# %%
#Power
2**2
# Out:
# 4

# %% [markdown]
# ### Variable Assignment

# %%
a = 5

# %%
a
# Out:
# 5

# %%
b = 3/2

# %%
type(b)
# Out:
# float

# %%
b
# Out:
# 1.5

# %%
a + b
# Out:
# 6.5

# %%
c=a+b

# %%
c
# Out:
# 6.5

# %%
type(c)
# Out:
# float

# %%
a
# Out:
# 5

# %%
a+a
# Out:
# 10

# %%
a
# Out:
# 5

# %%
a = a+a

# %%
a
# Out:
# 10

# %%
#Question
monthly_income = 100
tax_rate = 0.2
annual_tax = (100*12)*tax_rate
print(annual_tax)
# Out:
# 240.0

# %% [markdown]
# ### Dynamic Typing

# %%
mydogs = 2

# %%
mydogs = {"dog1":"Kunal","dog2":"Rohan"}

# %%
mydogs
# Out:
# {'dog1': 'Kunal', 'dog2': 'Rohan'}

# %%
type(mydogs)
# Out:
# dict
