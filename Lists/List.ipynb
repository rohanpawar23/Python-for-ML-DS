# %% [markdown]
# # List Basics

# %% [markdown]
# ### Things to remember About Lists:
# * They use [] brackets and commas to separate objects in the
# list.
# * Lists are mutable
# * Lists support indexing and slicing.
# * Lists can be nested.
# * Lists also have a variety of useful methods that can be
# called off of them.

# %%
my_list = [1,2,3]

# %%
type(my_list)
# Out:
# list

# %%
my_list1 = [" Rohan."," I'm",["Hi",4]]

# %%
my_list1[-1]
# Out:
# ['Hi', 4]

# %%
my_list1[-1][0] + my_list1[1] + my_list1[0]
# Out:
# "Hi I'm Rohan."

# %%
print(my_list1[-1][0] + my_list1[1] + my_list1[0])
# Out:
# Hi I'm Rohan.

# %%
len(my_list1)
# Out:
# 3

# %%
my_list1[-1][0].upper()
# Out:
# 'HI'

# %%
my_list1[-1][0].capitalize()
# Out:
# 'Hi'

# %%
#concatenation
my_list1 + [" I'm from Maharashtra",12]
# Out:
# [' Rohan.', " I'm", ['Hi', 4], " I'm from Maharashtra", 12]

# %%
my_list1 = my_list1 + ['Reassign to add new item permanently']

# %%
print(my_list1)
# Out:
# [' Rohan.', " I'm", ['Hi', 4], 'Reassign to add new item permanently']

# %%
my_list * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list = my_list * 2

# %%
my_list
# Out:
# [1, 2, 3, 1, 2, 3]

# %% [markdown]
# ### Basic List Method

# %%
#Append
new_list = [1,2,3,4]
new_list.append(5)                #Adding element permanently
new_list
# Out:
# [1, 2, 3, 4, 5]

# %%
new_list
# Out:
# [1, 2, 3, 4, 5]

# %%
v1 = new_list.append(6)       
v1
type(v1)
# Out:
# NoneType

# %%
new_list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Pop
new_list.pop() #It will pop out the last element
# Out:
# 6

# %%
v2 = new_list.pop()

# %%
v2
# Out:
# 5

# %%
new_list
# Out:
# [1, 2, 3, 4]

# %%
new_list.pop(0) #If we do enter anything in pop funtion it will by default consider the last item
# Out:
# 1

# %%
new_list
# Out:
# [2, 3, 4]

# %%
#Lists are mutable 
new_list[1] = 67

# %%
new_list
# Out:
# [2, 67, 4]

# %%
#Reverse
new_list.reverse()

# %%
new_list
# Out:
# [4, 67, 2]

# %%
#Sort 
new_list.sort() #Assending Order
new_list
# Out:
# [2, 4, 67]

# %%
new_list.sort(reverse = True) #Descending order use sort(reverse =True)
                    #it is applicable for alphabet also
new_list
# Out:
# [67, 4, 2]

# %%
new_list.sort()
new_list
# Out:
# [2, 4, 67]

# %%
#Append
new_list.append([68,69])
new_list
# Out:
# [2, 4, 67, [68, 69]]

# %%
l1 = [1,2,3,4,5]
#Append
l1.append([6,7])
l1
# Out:
# [1, 2, 3, 4, 5, [6, 7]]

# %%
l1.pop()
# Out:
# [6, 7]

# %%
l1.pop()
# Out:
# 5

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
#Extend
l1.extend([6,7])

# %%
l1
# Out:
# [1, 2, 3, 4, 6, 7]

# %%
#Index
l1.index(6)
# Out:
# 4

# %%
#Remove
l1.remove(6)
l1
# Out:
# ['HI', 1, 2, 3, 4, 7]

# %%
#Insert
l1.insert(0,"HI")

# %%
l1
# Out:
# ['HI', 1, 2, 3, 4, 6, 7]

# %%
l1
# Out:
# ['HI', 1, 2, 3, 4, 6, 7]
