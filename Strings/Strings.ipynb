# %% [markdown]
# ### Strings
# #### Things to remember
# * String is Unmutable i.e. we cannot change a string
# * It is written in Double("") or single quote('')

# %%
#Creating String 
"Hi I'm learning strings" #using double quote

# %%
#using Single qoute
'Hi I'm learning strings'

# %% [markdown]
# ### Printing String

# %%
print("Hi I'm learning strings") #using print statement this will not give me quote after printing

# %%
'Hello world 1'
'Hello world 2'

# %%
print('Hello world 1')
print('Hello world 2')

# %%
print('Hello world 1\nHello world 2')

# %%
s1 = "Hello"

# %%
s1

# %%
type(s1)

# %%
s2 = print("Hello")

# %%
type(s2)

# %%
len(s1)

# %%
s1[1]

# %% [markdown]
# ### Slicing

# %%
greeting = "Hello my name is rahul"

# %%
greeting[6:]

# %%
greeting[:5]

# %% [markdown]
# #### Word

# %%
random = "abababababababababab"

# %%
random[::1] #1 is by default

# %%
random[::2]

# %%
len(random[::2])

# %%
ran = "abcdabcdabcdabcd"

# %%
ran[::4]

# %%
ran[::3]

# %%
name = "Rohan"

# %%
name[::-1]

# %%
name + " pawar"

# %% [markdown]
# ### Useful Method

# %%
s = "Hello World"

# %%
s.capitalize() #Capitalize first letter

# %%
s.upper()

# %%
s.lower()

# %%
s.title()

# %%
s.count("H")

# %%
s.count("l")

# %%
s.find("o")

# %%
s.split() #this turns  string into a list

# %% [markdown]
# ### is check method

# %%
q = "car 23"

# %%
q.isalnum() #this checks that the string contains numer and alphabet both

# %%
q.isalpha()

# %%
q.isupper()

# %%
q.islower()

# %%
q.istitle()

# %%
q.isspace()
